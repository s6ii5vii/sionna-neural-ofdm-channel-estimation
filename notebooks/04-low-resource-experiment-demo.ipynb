# %% [markdown]
# # Low-resource experiment demo
#
# This notebook inspects the first constrained profile and runs its implemented LS (least-squares) portion. Neural training remains a separate, explicit step.

# %%
from pathlib import Path

from channel_estimation.config import load_config
from channel_estimation.evaluate import evaluate_ls

# %%
config = load_config(Path("../experiments/low-resource-v1/config.yaml"))
config["experiment"]

# %%
rows = evaluate_ls(config)
rows

# %% [markdown]
# The current sparse-pilot profile evaluates coefficients only at selected pilot locations. Interpolation across unobserved subcarriers is future work and must be implemented before claiming full-grid sparse-pilot performance.
